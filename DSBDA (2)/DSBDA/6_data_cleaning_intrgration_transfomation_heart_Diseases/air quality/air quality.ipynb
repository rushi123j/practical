# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("airquality - airquality.csv")
df

# to prtint first 10 rows
# df.head(10)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
# to find mean of each attribute
# df.mean()

# %%
#data cleaning
df.isnull()
# Out:
#      Unnamed: 0  Ozone  Solar.R   Wind   Temp  Month    Day
# 0         False  False    False  False  False  False  False
# 1         False  False    False  False  False  False  False
# 2         False  False    False  False  False  False  False
# 3         False  False    False  False  False  False  False
# 4         False   True     True  False  False  False  False
# ..          ...    ...      ...    ...    ...    ...    ...
# 148       False  False    False  False  False  False  False
# 149       False   True    False  False  False  False  False
# 150       False  False    False  False  False  False  False
# 151       False  False    False  False  False  False  False
# 152       False  False    False  False  False  False  False
#
# [153 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
# drop rows with missing values
df.dropna()
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
df.shape
# Out:
# (153, 7)

# %%
# Remove duplicate rows
df.drop_duplicates()
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
# replace NaN value with mean value
A = df['Ozone'].replace(np.NaN,df['Ozone'].mean())

# %%
A.head(10)
# Out:
# 0    41.00000
# 1    36.00000
# 2    12.00000
# 3    18.00000
# 4    42.12931
# 5    28.00000
# 6    23.00000
# 7    19.00000
# 8     8.00000
# 9    42.12931
# Name: Ozone, dtype: float64

# %%
#data integration

# %%
Df1 = df[['Ozone','Solar.R','Wind',]].loc[0:51]
Df1
# Out:
#     Ozone  Solar.R  Wind
# 0    41.0    190.0   7.4
# 1    36.0    118.0   8.0
# 2    12.0    149.0  12.6
# 3    18.0    313.0  11.5
# 4     NaN      NaN  14.3
# 5    28.0      NaN  14.9
# 6    23.0    299.0   8.6
# 7    19.0     99.0  13.8
# 8     8.0     19.0  20.1
# 9     NaN    194.0   8.6
# 10    7.0      NaN   6.9
# 11   16.0    256.0   9.7
# 12   11.0    290.0   9.2
# 13   14.0    274.0  10.9
# 14   18.0     65.0  13.2
# 15   14.0    334.0  11.5
# 16   34.0    307.0  12.0
# 17    6.0     78.0  18.4
# 18   30.0    322.0  11.5
# 19   11.0     44.0   9.7
# 20    1.0      8.0   9.7
# 21   11.0    320.0  16.6
# 22    4.0     25.0   9.7
# 23   32.0     92.0  12.0
# 24    NaN     66.0  16.6
# 25    NaN    266.0  14.9
# 26    NaN      NaN   8.0
# 27   23.0     13.0  12.0
# 28   45.0    252.0  14.9
# 29  115.0    223.0   5.7
# 30   37.0    279.0   7.4
# 31    NaN    286.0   8.6
# 32    NaN    287.0   9.7
# 33    NaN    242.0  16.1
# 34    NaN    186.0   9.2
# 35    NaN    220.0   8.6
# 36    NaN    264.0  14.3
# 37   29.0    127.0   9.7
# 38    NaN    273.0   6.9
# 39   71.0    291.0  13.8
# 40   39.0    323.0  11.5
# 41    NaN    259.0  10.9
# 42    NaN    250.0   9.2
# 43   23.0    148.0   8.0
# 44    NaN    332.0  13.8
# 45    NaN    322.0  11.5
# 46   21.0    191.0  14.9
# 47   37.0    284.0  20.7
# 48   20.0     37.0   9.2
# 49   12.0    120.0  11.5
# 50   13.0    137.0  10.3
# 51    NaN    150.0   6.3

# %%
Df2 = df[['Ozone','Solar.R','Wind',]].loc[51:100]
Df2
# Out:
#      Ozone  Solar.R  Wind
# 51     NaN    150.0   6.3
# 52     NaN     59.0   1.7
# 53     NaN     91.0   4.6
# 54     NaN    250.0   6.3
# 55     NaN    135.0   8.0
# 56     NaN    127.0   8.0
# 57     NaN     47.0  10.3
# 58     NaN     98.0  11.5
# 59     NaN     31.0  14.9
# 60     NaN    138.0   8.0
# 61   135.0    269.0   4.1
# 62    49.0    248.0   9.2
# 63    32.0    236.0   9.2
# 64     NaN    101.0  10.9
# 65    64.0    175.0   4.6
# 66    40.0    314.0  10.9
# 67    77.0    276.0   5.1
# 68    97.0    267.0   6.3
# 69    97.0    272.0   5.7
# 70    85.0    175.0   7.4
# 71     NaN    139.0   8.6
# 72    10.0    264.0  14.3
# 73    27.0    175.0  14.9
# 74     NaN    291.0  14.9
# 75     7.0     48.0  14.3
# 76    48.0    260.0   6.9
# 77    35.0    274.0  10.3
# 78    61.0    285.0   6.3
# 79    79.0    187.0   5.1
# 80    63.0    220.0  11.5
# 81    16.0      7.0   6.9
# 82     NaN    258.0   9.7
# 83     NaN    295.0  11.5
# 84    80.0    294.0   8.6
# 85   108.0    223.0   8.0
# 86    20.0     81.0   8.6
# 87    52.0     82.0  12.0
# 88    82.0    213.0   7.4
# 89    50.0    275.0   7.4
# 90    64.0    253.0   7.4
# 91    59.0    254.0   9.2
# 92    39.0     83.0   6.9
# 93     9.0     24.0  13.8
# 94    16.0     77.0   7.4
# 95    78.0      NaN   6.9
# 96    35.0      NaN   7.4
# 97    66.0      NaN   4.6
# 98   122.0    255.0   4.0
# 99    89.0    229.0  10.3
# 100  110.0    207.0   8.0

# %%
merging = pd.concat([Df1,Df2])
merging
# Out:
#      Ozone  Solar.R  Wind
# 0     41.0    190.0   7.4
# 1     36.0    118.0   8.0
# 2     12.0    149.0  12.6
# 3     18.0    313.0  11.5
# 4      NaN      NaN  14.3
# ..     ...      ...   ...
# 96    35.0      NaN   7.4
# 97    66.0      NaN   4.6
# 98   122.0    255.0   4.0
# 99    89.0    229.0  10.3
# 100  110.0    207.0   8.0
#
# [102 rows x 3 columns]

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
# data transpormation

df_encoded = pd.get_dummies(df, columns=['Day'])
df_encoded
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day_1  Day_2  Day_3  \
# 0             1   41.0    190.0   7.4    67      5   True  False  False
# 1             2   36.0    118.0   8.0    72      5  False   True  False
# 2             3   12.0    149.0  12.6    74      5  False  False   True
# 3             4   18.0    313.0  11.5    62      5  False  False  False
# 4             5    NaN      NaN  14.3    56      5  False  False  False
# ..          ...    ...      ...   ...   ...    ...    ...    ...    ...
# 148         149   30.0    193.0   6.9    70      9  False  False  False
# 149         150    NaN    145.0  13.2    77      9  False  False  False
# 150         151   14.0    191.0  14.3    75      9  False  False  False
# 151         152   18.0    131.0   8.0    76      9  False  False  False
# 152         153   20.0    223.0  11.5    68      9  False  False  False
#
#      Day_4  ...  Day_22  Day_23  Day_24  Day_25  Day_26  Day_27  Day_28  \
# 0    False  ...   False   False   False   False   False   False   False
# 1    False  ...   False   False   False   False   False   False   False
# 2    False  ...   False   False   False   False   False   False   False
# 3     True  ...   False   False   False   False   False   False   False
# 4    False  ...   False   False   False   False   False   False   False
# ..     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 148  False  ...   False   False   False   False    True   False   False
# 149  False  ...   False   False   False   False   False    True   False
# 150  False  ...   False   False   False   False   False   False    True
# 151  False  ...   False   False   False   False   False   False   False
# 152  False  ...   False   False   False   False   False   False   False
#
#      Day_29  Day_30  Day_31
# 0     False   False   False
# 1     False   False   False
# 2     False   False   False
# 3     False   False   False
# 4     False   False   False
# ..      ...     ...     ...
# 148   False   False   False
# 149   False   False   False
# 150   False   False   False
# 151    True   False   False
# 152   False    True   False
#
# [153 rows x 37 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
b  = scaler.fit_transform(df)

# %%
pd.DataFrame(b).describe()
# Out:
#                 0           1           2           3           4           5  \
# count  153.000000  116.000000  146.000000  153.000000  153.000000  153.000000
# mean     0.500000    0.246283    0.547191    0.434606    0.533716    0.498366
# std      0.291522    0.197532    0.275408    0.185421    0.230860    0.354131
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.250000    0.101796    0.332569    0.300000    0.390244    0.250000
# 50%      0.500000    0.182635    0.605505    0.421053    0.560976    0.500000
# 75%      0.750000    0.372754    0.769878    0.515789    0.707317    0.750000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6
# count  153.000000
# mean     0.493464
# std      0.295484
# min      0.000000
# 25%      0.233333
# 50%      0.500000
# 75%      0.733333
# max      1.000000

# %%
# error correction for gender

# Check for erroneous values
erroneous_values = df[~df['Month'].isin([0, 12])]

most_frequent_gender = df['Month'].mode()[0]
df.loc[erroneous_values.index, 'Month'] = most_frequent_gender
most_frequent_gender
# Out:
# 5

# %%
#model building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer 

imp = SimpleImputer(missing_values=np.nan,strategy='mean')

A = imp.fit_transform(df)
A = pd.DataFrame(A, columns=df.columns)
A
# Out:
#      Unnamed: 0     Ozone     Solar.R  Wind  Temp  Month   Day
# 0           1.0  41.00000  190.000000   7.4  67.0    5.0   1.0
# 1           2.0  36.00000  118.000000   8.0  72.0    5.0   2.0
# 2           3.0  12.00000  149.000000  12.6  74.0    5.0   3.0
# 3           4.0  18.00000  313.000000  11.5  62.0    5.0   4.0
# 4           5.0  42.12931  185.931507  14.3  56.0    5.0   5.0
# ..          ...       ...         ...   ...   ...    ...   ...
# 148       149.0  30.00000  193.000000   6.9  70.0    5.0  26.0
# 149       150.0  42.12931  145.000000  13.2  77.0    5.0  27.0
# 150       151.0  14.00000  191.000000  14.3  75.0    5.0  28.0
# 151       152.0  18.00000  131.000000   8.0  76.0    5.0  29.0
# 152       153.0  20.00000  223.000000  11.5  68.0    5.0  30.0
#
# [153 rows x 7 columns]

# %%
X=A['Ozone'].values
X=X.reshape(-1,1)

Y = A['Temp']

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.score(X,Y)*100
# Out:
# 37.056682983646425

# %%
model.predict([[128]])
# Out:
# array([95.12601986])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)
