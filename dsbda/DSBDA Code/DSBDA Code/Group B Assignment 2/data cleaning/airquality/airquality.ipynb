# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
df = pd.read_csv("airquality.csv")
df.head(10)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5
# 5           6   28.0      NaN  14.9    66      5    6
# 6           7   23.0    299.0   8.6    65      5    7
# 7           8   19.0     99.0  13.8    59      5    8
# 8           9    8.0     19.0  20.1    61      5    9
# 9          10    NaN    194.0   8.6    69      5   10

# %%
df.mean()
# Out:
# Unnamed: 0     77.000000
# Ozone          42.129310
# Solar.R       185.931507
# Wind            9.957516
# Temp           77.882353
# Month           6.993464
# Day            15.803922
# dtype: float64

# %%
#data cleaning

# %%
df.isnull()
# Out:
#      Unnamed: 0  Ozone  Solar.R   Wind   Temp  Month    Day
# 0         False  False    False  False  False  False  False
# 1         False  False    False  False  False  False  False
# 2         False  False    False  False  False  False  False
# 3         False  False    False  False  False  False  False
# 4         False   True     True  False  False  False  False
# ..          ...    ...      ...    ...    ...    ...    ...
# 148       False  False    False  False  False  False  False
# 149       False   True    False  False  False  False  False
# 150       False  False    False  False  False  False  False
# 151       False  False    False  False  False  False  False
# 152       False  False    False  False  False  False  False
#
# [153 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
df.dropna()
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 6             7   23.0    299.0   8.6    65      5    7
# ..          ...    ...      ...   ...   ...    ...  ...
# 147         148   14.0     20.0  16.6    63      9   25
# 148         149   30.0    193.0   6.9    70      9   26
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [111 rows x 7 columns]

# %%
df.drop(["Ozone","Solar.R"],inplace=True,axis=1)

# %%
df
# Out:
#      Unnamed: 0  Wind  Temp  Month  Day
# 0             1   7.4    67      5    1
# 1             2   8.0    72      5    2
# 2             3  12.6    74      5    3
# 3             4  11.5    62      5    4
# 4             5  14.3    56      5    5
# ..          ...   ...   ...    ...  ...
# 148         149   6.9    70      9   26
# 149         150  13.2    77      9   27
# 150         151  14.3    75      9   28
# 151         152   8.0    76      9   29
# 152         153  11.5    68      9   30
#
# [153 rows x 5 columns]

# %%
#data integration

# %%
df1 = sr[['Wind','Temp','Month','Day']].loc[0:26]
df1
# Out:
#     Wind  Temp  Month  Day
# 0    7.4    67      5    1
# 1    8.0    72      5    2
# 2   12.6    74      5    3
# 3   11.5    62      5    4
# 4   14.3    56      5    5
# 5   14.9    66      5    6
# 6    8.6    65      5    7
# 7   13.8    59      5    8
# 8   20.1    61      5    9
# 9    8.6    69      5   10
# 10   6.9    74      5   11
# 11   9.7    69      5   12
# 12   9.2    66      5   13
# 13  10.9    68      5   14
# 14  13.2    58      5   15
# 15  11.5    64      5   16
# 16  12.0    66      5   17
# 17  18.4    57      5   18
# 18  11.5    68      5   19
# 19   9.7    62      5   20
# 20   9.7    59      5   21
# 21  16.6    73      5   22
# 22   9.7    61      5   23
# 23  12.0    61      5   24
# 24  16.6    57      5   25
# 25  14.9    58      5   26
# 26   8.0    57      5   27

# %%
df2 = sr[['Wind','Temp','Month','Day']].loc[26:55]
df2
# Out:
#     Wind  Temp  Month  Day
# 26   8.0    57      5   27
# 27  12.0    67      5   28
# 28  14.9    81      5   29
# 29   5.7    79      5   30
# 30   7.4    76      5   31
# 31   8.6    78      6    1
# 32   9.7    74      6    2
# 33  16.1    67      6    3
# 34   9.2    84      6    4
# 35   8.6    85      6    5
# 36  14.3    79      6    6
# 37   9.7    82      6    7
# 38   6.9    87      6    8
# 39  13.8    90      6    9
# 40  11.5    87      6   10
# 41  10.9    93      6   11
# 42   9.2    92      6   12
# 43   8.0    82      6   13
# 44  13.8    80      6   14
# 45  11.5    79      6   15
# 46  14.9    77      6   16
# 47  20.7    72      6   17
# 48   9.2    65      6   18
# 49  11.5    73      6   19
# 50  10.3    76      6   20
# 51   6.3    77      6   21
# 52   1.7    76      6   22
# 53   4.6    76      6   23
# 54   6.3    76      6   24
# 55   8.0    75      6   25

# %%
merging = pd.concat([df1,df2])
merging
# Out:
#     Wind  Temp  Month  Day
# 0    7.4    67      5    1
# 1    8.0    72      5    2
# 2   12.6    74      5    3
# 3   11.5    62      5    4
# 4   14.3    56      5    5
# 5   14.9    66      5    6
# 6    8.6    65      5    7
# 7   13.8    59      5    8
# 8   20.1    61      5    9
# 9    8.6    69      5   10
# 10   6.9    74      5   11
# 11   9.7    69      5   12
# 12   9.2    66      5   13
# 13  10.9    68      5   14
# 14  13.2    58      5   15
# 15  11.5    64      5   16
# 16  12.0    66      5   17
# 17  18.4    57      5   18
# 18  11.5    68      5   19
# 19   9.7    62      5   20
# 20   9.7    59      5   21
# 21  16.6    73      5   22
# 22   9.7    61      5   23
# 23  12.0    61      5   24
# 24  16.6    57      5   25
# 25  14.9    58      5   26
# 26   8.0    57      5   27
# 26   8.0    57      5   27
# 27  12.0    67      5   28
# 28  14.9    81      5   29
# 29   5.7    79      5   30
# 30   7.4    76      5   31
# 31   8.6    78      6    1
# ...

# %%
#model building

# %%
#linear regression

# %%
# Import the function linear model and metrics
from sklearn import linear_model, metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
#data types of all columns
df.dtypes
# Out:
# Unnamed: 0      int64
# Wind          float64
# Temp            int64
# Month           int64
# Day             int64
# dtype: object

# %%
# X is input and Y is output
X=df[["Temp"]]
Y=df[["Month"]]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
# No. of samples in train dataset
len(X_train)
# Out:
# 122

# %%
# No. of samples in test dataset
len(X_test)
# Out:
# 31

# %%
df.shape
# Out:
# (153, 5)

# %%
reg = LinearRegression()

# %%
#fit function gives us the best fit linear regression line
model = reg.fit(X_train, Y_train)

# %%
Y_pred = model.predict(X_test)
print('predicted response:', Y_pred, sep='\n')
# Out:
# predicted response:
# [[6.98378371]
#  [6.33152508]
#  [7.96217164]
#  [7.63604233]
#  [7.04900957]
#  [6.98378371]
#  [7.63604233]
#  [5.74449232]
#  [6.91855784]
#  [7.17946129]
#  [6.07062163]
#  [7.04900957]
#  [7.44036474]
#  [7.57081647]
#  [6.26629922]
#  [7.5055906 ]
#  [6.26629922]
#  [7.83171991]
#  [7.57081647]
#  [7.57081647]
#  [7.24468715]
#  [7.96217164]
#  [7.24468715]
#  [7.83171991]
#  [7.24468715]
#  [7.63604233]
#  [7.11423543]
#  [7.96217164]
#  [6.91855784]
#  [8.09262336]
#  [7.5055906 ]]

# %%
Y_pred=model.predict(X_test)
# Calculate evaluation metrics
r2 = r2_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(Y_test, Y_pred)

# Print the evaluation metrics
print("R-squared:", r2)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):",mae)
# Out:
# R-squared: 0.15784985413975494
# Mean Squared Error (MSE): 1.3583066868713631
# Root Mean Squared Error (RMSE): 1.1654641508306307
# Mean Absolute Error (MAE): 0.9696826386104331

# %%
plt.scatter(X_test, Y_test, color='red')
plt.plot(X_test, reg.predict(X_test), color='black', linewidth=3)
plt.title("Quality of Air")
plt.xlabel("Temperature")
plt.ylabel("Month")
plt.show()
